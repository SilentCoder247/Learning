# %% [markdown]
# # Linear Regression Practical Implementation -- fetch_california_housing mathod -- 1

# %%
 import pandas as pd

# %%
from sklearn.datasets import fetch_california_housing

# %%
import  numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_excel('/kaggle/input/fetch-california-housing/fetch_california_housing.xlsx')

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252        41  6.984127   1.023810         322  2.555556     37.88
# 1      8.3014        21  6.238137   0.971880        2401  2.109842     37.86
# 2      7.2574        52  8.288136   1.073446         496  2.802260     37.85
# 3      5.6431        52  5.817352   1.073059         558  2.547945     37.85
# 4      3.8462        52  6.281853   1.081081         565  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603        25  5.045455   1.133333         845  2.560606     39.48
# 20636  2.5568        18  6.114035   1.315789         356  3.122807     39.49
# 20637  1.7000        17  5.205543   1.120092        1007  2.325635     39.43
# 20638  1.8672        18  5.329513   1.171920         741  2.123209     39.43
# 20639  2.3886        16  5.254717   1.162264        1387  2.616981     39.37
#
#        Longitude  target
# ...

# %%
# df= fetch_california_housing() # data frame make

# %%
# df

# %%
# dataset = pd.DataFrame(df.data) #

# %%
# dataset.head()

# %%
# dataset.columns=df.feature_names # give name to coolumn as feature

# %%
# dataset.head()

# %%
# independant feature  and dependant feature

# %%
X = df.drop('target',axis=1)

# %%
X
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252        41  6.984127   1.023810         322  2.555556     37.88
# 1      8.3014        21  6.238137   0.971880        2401  2.109842     37.86
# 2      7.2574        52  8.288136   1.073446         496  2.802260     37.85
# 3      5.6431        52  5.817352   1.073059         558  2.547945     37.85
# 4      3.8462        52  6.281853   1.081081         565  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603        25  5.045455   1.133333         845  2.560606     39.48
# 20636  2.5568        18  6.114035   1.315789         356  3.122807     39.49
# 20637  1.7000        17  5.205543   1.120092        1007  2.325635     39.43
# 20638  1.8672        18  5.329513   1.171920         741  2.123209     39.43
# 20639  2.3886        16  5.254717   1.162264        1387  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
X
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252        41  6.984127   1.023810         322  2.555556     37.88
# 1      8.3014        21  6.238137   0.971880        2401  2.109842     37.86
# 2      7.2574        52  8.288136   1.073446         496  2.802260     37.85
# 3      5.6431        52  5.817352   1.073059         558  2.547945     37.85
# 4      3.8462        52  6.281853   1.081081         565  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603        25  5.045455   1.133333         845  2.560606     39.48
# 20636  2.5568        18  6.114035   1.315789         356  3.122807     39.49
# 20637  1.7000        17  5.205543   1.120092        1007  2.325635     39.43
# 20638  1.8672        18  5.329513   1.171920         741  2.123209     39.43
# 20639  2.3886        16  5.254717   1.162264        1387  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
X.head(2)
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252        41  6.984127    1.02381         322  2.555556     37.88
# 1  8.3014        21  6.238137    0.97188        2401  2.109842     37.86
#
#    Longitude
# 0    -122.23
# 1    -122.22

# %%
y = df.target # dependant feature

# %%
y # tit is as an numpy
# Out:
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: target, Length: 20640, dtype: float64

# %%
# train test split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.30,random_state = 42)

# %%
X_train.head(2)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 7061   4.1312        35  5.882353   0.975490        1218  2.985294     33.93
# 14689  2.8631        20  4.401210   1.076613         999  2.014113     32.79
#
#        Longitude
# 7061     -118.02
# 14689    -117.09

# %%
y_train
# Out:
# 7061     1.93800
# 14689    1.69700
# 17323    2.59800
# 10056    1.36100
# 15750    5.00001
#           ...
# 11284    2.29200
# 11964    0.97800
# 5390     2.22100
# 860      2.83500
# 15795    3.25000
# Name: target, Length: 14448, dtype: float64

# %%
# apply Linear regration

# %%
## fisrt make standardiation on dataset 

# we alway apply fit transform ---- x_trai 
# we alway apply tranform  ---- x_test




### but but We never apply tranform on out put variable

# %%
# standardizing the dataset

# %%
 from sklearn.preprocessing import StandardScaler

# %%
# initilization of standard  SCALER 
scaler = StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 0.13350629,  0.50935748,  0.18106017, ..., -0.01082519,
#         -0.80568191,  0.78093406],
#        [-0.53221805, -0.67987313, -0.42262953, ..., -0.08931585,
#         -1.33947268,  1.24526986],
#        [ 0.1709897 , -0.36274497,  0.07312833, ..., -0.04480037,
#         -0.49664515, -0.27755183],
#        ...,
#        [-0.49478713,  0.58863952, -0.59156984, ...,  0.01720102,
#         -0.75885816,  0.60119118],
#        [ 0.96717102, -1.07628333,  0.39014889, ...,  0.00482125,
#          0.90338501, -1.18625198],
#        [-0.68320166,  1.85715216, -0.82965604, ..., -0.0816717 ,
#          0.99235014, -1.41592345]])

# %%
X_test=scaler.transform(X_test)

# %%
X_test
# Out:
# array([[-1.1526893 , -0.28346293, -0.50781822, ...,  0.06127763,
#          0.19166399,  0.28664112],
#        [-0.70640568,  0.11294728, -0.16252032, ..., -0.03551561,
#         -0.23911452,  0.06196251],
#        [-0.20830675,  1.85715216, -0.59546738, ..., -0.14215427,
#          1.00639726, -1.42590916],
#        ...,
#        [-0.19155996, -0.99700129, -0.6830438 , ..., -0.06058827,
#         -0.92742367,  0.8358555 ],
#        [-0.11911302, -1.47269353,  0.02607207, ...,  0.03461374,
#          1.01576201, -0.84673764],
#        [-0.43304974, -0.91771925, -0.84872893, ..., -0.0407528 ,
#         -0.70266966,  0.67109119]])

# %%
# now we standar dize our data

# %%
# let's make our model now 
from sklearn.linear_model import LinearRegression

# %%
# cross validation  
from sklearn.model_selection import cross_val_score

# %%
regression = LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
mse = cross_val_score (regression,X_train,y_train,scoring='neg_mean_squared_error',cv=5)

# %%
np.mean(mse)
# Out:
# -0.5268253746355749

# %%
# Prediction

# %%
reg_Pred=regression.predict(X_test)

# %%
reg_Pred
# Out:
# array([0.72604907, 1.76743383, 2.71092161, ..., 2.07465531, 1.57371395,
#        1.82744133])

# %%
import seaborn as sns

# %%
sns.displot(reg_Pred-y_test,kind='kde')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
from sklearn.metrics import r2_score

# %%
score = r2_score(reg_Pred,y_test)

# %%
score
# Out:
# 0.34513393809439896
